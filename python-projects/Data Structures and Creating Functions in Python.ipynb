# %% [markdown]
# ## Mission 1: Data Structures and Creating Functions in Python
#
# **Exercise 1**
# Create a tuple that contains three numbers and print the last number from the tuple.
#
# **Exercise 2:**
# Create two sets and perform a union and an intersection operation between them.
#
# **Exercise 3:**
# Create a dictionary for a book with keys title, author, and year, and print the value for the author key.
#
# **Exercise 4**
# Create a list of your three favorite fruits and print the second fruit from the list.
#
# **Exercise 5: Control Structures**
# Write a program that asks for your age and prints whether you are eligible to vote (18 or older).
#
# **Exercise 6: Functions**
# Create a function that takes two numbers and returns their difference. Call the function with different numbers and print the result.

# %%
Joses_Book =  {"Book_Name": "Counting Miracles", "Author": "Nicolas Spark", "Year": 2025}
print(Joses_Book["Book_Name"])
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 3, Finished, Available, Finished, False)
# Counting Miracles

# %%
# Code Here Exercise 1

print("Hello from Fabric")
# Out:
# StatementMeta(, 64f3de7f-0e3a-4496-a4c1-c114512f4859, 14, Finished, Cancelled, Cancelled, False)
# Hello from Fabric

# %%
# Code Here Exercise 2
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 5, Finished, Available, Finished, False)

# %%
# Code Here Exercise 3
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 6, Finished, Available, Finished, False)

# %%
# Code Here Exercise 4

fruit_list = ['pineapple', 'mango', 'passionfruit']
print(fruit_list)
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 7, Finished, Available, Finished, False)
# ['pineapple', 'mango', 'passionfruit']

# %%
print(fruit_list [1])
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 8, Finished, Available, Finished, False)
# mango

# %%
# Code Here Exercise 5

age = 16

if age >= 18:
    print("You can vote")
else:
    print("You cannot vote yet")

print("✅ Finished running")
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 9, Finished, Available, Finished, False)
# You cannot vote yet
# ✅ Finished running

# %%
x = 10 # This is how to comment
print(x) # Output: 10
# Out:
# StatementMeta(, 64f3de7f-0e3a-4496-a4c1-c114512f4859, 15, Finished, Cancelled, Cancelled, False)

# %%
#  Code Here Exercise 6
# Out:
# StatementMeta(, 7f8b2a92-482f-454d-83ba-aacd39dcce20, 10, Finished, Available, Finished, False)

# %% [markdown]
# Please complete the mission.
